# %% [markdown]
# #Transformação dos dados - totalCases_per_100k_inhabitants
#
# Fonte: Wesley Cota

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
filename = "https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv"
df = pd.read_csv(filename)

# %%
['epi_week','country','newDeaths','deaths','newCases',	'totalCases',	'deathsMS',	'totalCasesMS',	'deaths_per_100k_inhabitants',	'totalCases_per_100k_inhabitants',	'deaths_by_totalCases',	'recovered','suspects','tests','tests_per_100k_inhabitants']
# Out:
# ['epi_week',
#  'country',
#  'newDeaths',
#  'deaths',
#  'newCases',
#  'totalCases',
#  'deathsMS',
#  'totalCasesMS',
#  'deaths_per_100k_inhabitants',
#  'totalCases_per_100k_inhabitants',
#  'deaths_by_totalCases',
#  'recovered',
#  'suspects',
#  'tests',
#  'tests_per_100k_inhabitants']

# %% [markdown]
# #Cleaning SP

# %%
df_sp = df[df['state'] == 'SP']
df_sp.head()
df_sp.groupby(['date']).sum()
df_sp_newdeath = df_sp.drop(columns=['epi_week','country','newDeaths','deaths',	'newCases',	'totalCases',	'deathsMS',	'totalCasesMS',	'deaths_per_100k_inhabitants',	'deaths_by_totalCases',	'recovered','suspects','tests','tests_per_100k_inhabitants'])
df_sp_transposed = df_sp_newdeath.transpose()
df_sp_clean = df_sp_transposed.drop(index = ['state','city'])
df_sp_clean.columns = df_sp_clean.iloc[0]
df_sp_clean = df_sp_clean.drop('date')
df_sp_clean['state'] = 'SP'
df_sp_clean
# Out:
# date                            2020-02-25 2020-02-26  ... 2020-07-07 state
# totalCases_per_100k_inhabitants    0.00218    0.00218  ...    724.553    SP
#
# [1 rows x 135 columns]

# %%
df_total = pd.DataFrame()
def select_columns(data_frame, column_names):
    new_frame = data_frame.loc[:, column_names]
    return new_frame

# %%
df_total = select_columns(df_sp_clean,df_sp_clean.columns)

# %% [markdown]
# # Appending States

# %%
for estado in df['state'].unique():
  df_al = df[df['state'] == estado]
  df_al.groupby(['date']).sum()
  df_al_newdeath = df_al.drop(columns=['epi_week','country','newDeaths','newCases',	'deaths',	'newCases',	'deathsMS',	'totalCasesMS',	'deaths_per_100k_inhabitants',	'deaths_by_totalCases',	'recovered','suspects','tests','tests_per_100k_inhabitants'])
  df_al_transposed = df_al_newdeath.transpose()
  df_al_clean = df_al_transposed.drop(index = ['state','city'])
  df_al_clean.columns = df_al_clean.iloc[0]
  df_al_clean = df_al_clean.drop('date')
  df_al_clean['state'] = estado
  df_total = df_total.append(df_al_clean)

# %% [markdown]
# #Dropping duplicates

# %%
df_total.sort_values('state', inplace= True)
df_total.drop_duplicates(subset ="state", keep = 'first', inplace = True)

# %%
df_total
# Out:
#                                 2020-02-25 2020-02-26  ... 2020-07-07  state
# totalCases                             NaN        NaN  ...      14941     AC
# totalCases_per_100k_inhabitants        NaN        NaN  ...    1244.22     AL
# totalCases                             NaN        NaN  ...      79167     AM
# totalCases                             NaN        NaN  ...      30294     AP
# totalCases                             NaN        NaN  ...      91954     BA
# totalCases                             NaN        NaN  ...     126142     CE
# totalCases                             NaN        NaN  ...      62694     DF
# totalCases_per_100k_inhabitants        NaN        NaN  ...       1411     ES
# totalCases                             NaN        NaN  ...      32001     GO
# totalCases                             NaN        NaN  ...      92088     MA
# totalCases_per_100k_inhabitants        NaN        NaN  ...    287.673     MG
# totalCases_per_100k_inhabitants        NaN        NaN  ...    384.565     MS
# totalCases                             NaN        NaN  ...      23506     MT
# totalCases                             NaN        NaN  ...     118744     PA
# totalCases                             NaN        NaN  ...      54802     PB
# totalCases                             NaN        NaN  ...      66151     PE
# totalCases                             NaN        NaN  ...      28411     PI
# totalCases_per_100k_inhabitants        NaN        NaN  ...    300.062     PR
# totalCases_per_100k_inhabitants        NaN        NaN  ...    718.717     RJ
# totalCases_per_100k_inhabitants        NaN        NaN  ...    1021.43     RN
# totalCases                             NaN        NaN  ...      24564     RO
# totalCases                             NaN        NaN  ...      19284     RR
# totalCases_per_100k_inhabitants        NaN        NaN  ...    297.084     RS
# totalCases_per_100k_inhabitants        NaN        NaN  ...    493.287     SC
# totalCases_per_100k_inhabitants        NaN        NaN  ...    1376.43     SE
# totalCases_per_100k_inhabitants    0.00218    0.00218  ...    724.553     SP
# totalCases                             NaN        NaN  ...      13004     TO
# totalCases_per_100k_inhabitants    0.00048    0.00048  ...    797.186  TOTAL
#
# [28 rows x 135 columns]

# %% [markdown]
# #To CSV

# %%
df_total.to_csv()
# Out:
# ',2020-02-25,2020-02-26,2020-02-27,2020-02-28,2020-02-29,2020-03-01,2020-03-02,2020-03-03,2020-03-04,2020-03-05,2020-03-06,2020-03-07,2020-03-08,2020-03-09,2020-03-10,2020-03-11,2020-03-12,2020-03-13,2020-03-14,2020-03-15,2020-03-16,2020-03-17,2020-03-18,2020-03-19,2020-03-20,2020-03-21,2020-03-22,2020-03-23,2020-03-24,2020-03-25,2020-03-26,2020-03-27,2020-03-28,2020-03-29,2020-03-30,2020-03-31,2020-04-01,2020-04-02,2020-04-03,2020-04-04,2020-04-05,2020-04-06,2020-04-07,2020-04-08,2020-04-09,2020-04-10,2020-04-11,2020-04-12,2020-04-13,2020-04-14,2020-04-15,2020-04-16,2020-04-17,2020-04-18,2020-04-19,2020-04-20,2020-04-21,2020-04-22,2020-04-23,2020-04-24,2020-04-25,2020-04-26,2020-04-27,2020-04-28,2020-04-29,2020-04-30,2020-05-01,2020-05-02,2020-05-03,2020-05-04,2020-05-05,2020-05-06,2020-05-07,2020-05-08,2020-05-09,2020-05-10,2020-05-11,2020-05-12,2020-05-13,2020-05-14,2020-05-15,2020-05-16,2020-05-17,2020-05-18,2020-05-19,2020-05-20,2020-05-21,2020-05-22,2020-05-23,2020-05-24,2020-05-25,2020-05-26,2020-05-27,2020-05-28,2020-05-29,2020-05-30,2020-05-31,2020-06-01,2020-06-02,2020-06-03,2020-06-04,2020-06-05,2020-06-06,2020-06-07,2020-06-08,2020-06-09,2020-06-10,2020-06-11,2020-06-12,2020-06-13,2020-06-14,2020-06-15,2020-06-16,2020-06-17,2020-06-18,2020-06-19,2020-06-20,2020-06-21,2020-06-22,2020-06-23,2020-06-24,2020-06-25,2020-06-26,2020-06-27,2020-06-28,2020-06-29,2020-06-30,2020-07-01,2020-07-02,2020-07-03,2020-07-04,2020-07-05,2020-07-06,2020-07-07,state\ntotalCases,,,,,,,,,,,,,,,,,,,,,,3,3,4,7,11,11,17,21,23,24,25,25,34,42,42,43,45,46,46,48,50,50,58,62,70,72,77,90,99,101,115,135,142,163,176,195,214,227,234,258,279,301,317,354,404,487,553,658,733,817,943,1014,1177,1335,1447,1460,1590,1694,1740,1785,1867,1997,2234,2482,2817,3103,3343,3867,4160,4501,4781,5251,5600,5841,6072,6219,6326,6465,6679,7021,7284,7525,7983,8128,8457,8746,9091,9295,9534,9642,9771,10003,10339,10664,10987,11263,11381,11539,11810,12022,12304,12644,12913,13058,13146,13253,13715,14048,14112,14487,14622,14688,14941,AC\ntotalCases_per_100k_inhabitants,,,,,,,,,,,,,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.029960000000000004,0.11986,0.17978,0.20975,0.20975,0.23970999999999998,0.29964,0.3296,0.3296,0.35957,0.41949,0.50939,0.50939,0.53935,0.53935,0.53935,0.68917,0.68917,0.83899,0.9288799999999999,1.0187700000000002,1.10866,1.10866,1.34837,1.43826,1.43826,1.7379,2.1574,2.487,2.6667799999999997,3.2960199999999995,3.9552300000000002,4.76425,5.123819999999999,6.2924,7.281210000000001,9.70828,12.375060000000001,15.01188,16.77975,19.26674,23.2819,28.675390000000004,31.3122,36.735659999999996,41.11038,43.17788,46.08437,48.12191,51.0284,55.94246999999999,60.91647,65.08144,67.65833,70.20526,77.30668,82.73014,89.0525,96.24382,107.66004,114.34198,120.7842,129.41378,132.94952,147.30219,158.86823,168.69637,186.19523999999998,200.21832,211.48472,227.12583999999998,241.38862000000003,258.25826,276.35641,308.26788999999997,324.71803,346.35192,371.76125,392.43629,417.66584,444.00404000000003,470.64189000000005,489.60899000000006,515.16814,544.6225900000001,575.30555,600.20549,625.85453,665.1670799999999,688.02948,708.10525,745.11058,768.06287,806.20683,829.93818,858.6735,880.7868,906.34595,935.77043,960.7902300000001,984.7313300000001,1004.41757,1028.11896,1052.23984,1077.5592800000002,1103.23828,1118.4898699999999,1150.73095,1176.2301699999998,1196.6055800000001,1215.60265,1244.2181,AL\ntotalCases,,,,,,,,,,,,,,,,,,2,2,2,2,2,2,3,7,11,26,32,47,54,67,81,111,140,151,175,200,229,260,311,417,532,636,804,899,981,1050,1206,1275,1484,1554,1719,1809,1897,2044,2160,2270,2479,2888,3194,3635,3833,3928,4337,4801,5254,5723,6062,6683,7313,8109,9243,10099,10727,11925,12599,12919,14168,15816,17181,18392,19677,20328,20913,22132,23704,25367,27038,28802,29867,30282,31949,33508,36146,38909,40560,41378,41774,43195,44347,46473,47666,487 ...
